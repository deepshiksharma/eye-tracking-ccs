# %%
from experiment_specific_utils.pupil_diameter import compute_mean_sd, run_ttests

# to supress pandas incorrect usage warning
import warnings
warnings.filterwarnings("ignore", message="dropping on a non-lexsorted multi-index")

# %%
# The directory containing a subdirectory for each subject, where each subdir contains eye_tracking_data.csv for that subject.
# 
# The directory structure:
#   
#   |-- base_dir/
#   |   |-- subject_1/
#   |   |   |-- eye_tracking_data.csv
#   |   |...
#   |   |-- subject_n/
#   |   |   |-- eye_tracking_data.csv

base_dir = r"eye-data-sept2025\EXPERIMENTS_selective"

# %%
group_lvl_summary, subject_lvl_summary = compute_mean_sd(base_dir)
# Out:
# D:\GITHUB\eye-tracking-ccs\preprocessing and analysis\experiment_specific_utils\pupil_diameter.py:21: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(s, "eye_tracking_data.csv"))
# Saved group and subject level summaries to csv.

# %%
run_ttests(subject_lvl_summary)
# Out:
# Left pupil (baseline-corrected):
# Positive vs Negative: t=-1.56350, p=0.15237
# Positive vs Neutral: t=0.84230, p=0.42144
# Negative vs Neutral: t=2.09572, p=0.06557
#
# Right pupil (baseline-corrected):
# Positive vs Negative: t=-0.87639, p=0.40360
# Positive vs Neutral: t=1.36541, p=0.20527
# Negative vs Neutral: t=2.13279, p=0.06174
#
# Left vs Right pupil (baseline-corrected):
# Negative: t=1.81223, p=0.10337
# Neutral: t=2.57027, p=0.03017
# Positive: t=-0.08154, p=0.93680
