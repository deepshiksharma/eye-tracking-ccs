# %% [markdown]
# ## Preprocessing
# Includes removal of invalid data, smoothing, and subtractive baseline-correction.

# %% [markdown]
# ## Analysis
# Includes mean and sd of pupil diameters per emotion category (both absolute and baseline-corrected values), and tests of statistical significance.

# %%
from utils.pupildiameter import compute_mean_sd, run_ttests

# %%
base_dir = r"eye-data-sept2025\EXPERIMENTS_selective"

# %%
group_lvl_summary, subject_lvl_summary = compute_mean_sd(base_dir)
# Out:
# input dataframe size: 474394
# ouput dataframe size: 460956
# number of segments removed: 29
# total number of rows removed: 13438
# d:\GITHUB\eye-tracking-ccs\preprocessing & analysis\utils\pupildiameter.py:210: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   agg = pd.merge(agg_abs, agg_bc, on="stim_cat", how="outer", suffixes=("_abs", "_bc"))
# input dataframe size: 634244
# ouput dataframe size: 536051
# number of segments removed: 219
# total number of rows removed: 98193
# d:\GITHUB\eye-tracking-ccs\preprocessing & analysis\utils\pupildiameter.py:210: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   agg = pd.merge(agg_abs, agg_bc, on="stim_cat", how="outer", suffixes=("_abs", "_bc"))
# input dataframe size: 566560
# ouput dataframe size: 437373
# number of segments removed: 255
# total number of rows removed: 129187
# ...

# %%
run_ttests(subject_lvl_summary)
# Out:
# Left pupil (baseline-corrected):
# Positive vs Negative: t=-1.83560, p=0.09961
# Positive vs Neutral: t=0.86137, p=0.41140
# Negative vs Neutral: t=2.82264, p=0.01996
#
# Right pupil (baseline-corrected):
# Positive vs Negative: t=-1.46425, p=0.17716
# Positive vs Neutral: t=1.20978, p=0.25718
# Negative vs Neutral: t=2.80067, p=0.02069
#
# Left vs Right pupil (baseline-corrected):
# Negative: t=2.40691, p=0.03945
# Neutral: t=3.42475, p=0.00757
# Positive: t=1.13248, p=0.28670
